# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("B:\Tree_dataset\cjs.csv")
df.head()
# Out:
#    N       TR TREE BR    TL  IN  INTERNODE_1 INTERNODE_2 INTERNODE_3  \
# 0  1  control  G28  A  75.0  15          1.0         2.3         7.4
# 1  2  control  G28  B  18.0   7          0.7         1.3         4.0
# 2  3  control  G28  C  46.0  11          0.5         1.0         4.3
# 3  4  control  G28  C  16.0   8          0.5         1.2         3.5
# 4  5  control  G28  D  56.0  16          0.5         1.0         3.5
#
#   INTERNODE_4  ... INTERNODE_20 INTERNODE_21 INTERNODE_22 INTERNODE_23  \
# 0         8.6  ...            ?            ?            ?            ?
# 1         5.2  ...            ?            ?            ?            ?
# 2         8.8  ...            ?            ?            ?            ?
# 3         4.2  ...            ?            ?            ?            ?
# 4         8.2  ...            ?            ?            ?            ?
#
#   INTERNODE_24 INTERNODE_25 INTERNODE_26 INTERNODE_27 INTERNODE_28  \
# 0            ?            ?            ?            ?            ?
# 1            ?            ?            ?            ?            ?
# 2            ?            ?            ?            ?            ?
# 3            ?            ?            ?            ?            ?
# 4            ?            ?            ?            ?            ?
#
#   INTERNODE_29
# 0            ?
# 1            ?
# 2            ?
# 3            ?
# 4            ?
#
# [5 rows x 35 columns]

# %%
df.tail()
# Out:
#          N           TR TREE BR   TL  IN  INTERNODE_1 INTERNODE_2 INTERNODE_3  \
# 2791  2792  EL_500_4g/L  G24  I  1.0   4          0.3         0.3         0.3
# 2792  2793  EL_500_4g/L  G24  I  1.0   4          0.3         0.3         0.3
# 2793  2794  EL_500_4g/L  G24  I  1.0   4          0.3         0.3         0.3
# 2794  2795  EL_500_4g/L  G24  I  1.0   4          0.2         0.2         0.2
# 2795  2796  EL_500_4g/L  G24  I  1.0   3          0.3         0.3         0.3
#
#      INTERNODE_4  ... INTERNODE_20 INTERNODE_21 INTERNODE_22 INTERNODE_23  \
# 2791         0.3  ...            ?            ?            ?            ?
# 2792         0.3  ...            ?            ?            ?            ?
# 2793         0.3  ...            ?            ?            ?            ?
# 2794         0.2  ...            ?            ?            ?            ?
# 2795           ?  ...            ?            ?            ?            ?
#
#      INTERNODE_24 INTERNODE_25 INTERNODE_26 INTERNODE_27 INTERNODE_28  \
# 2791            ?            ?            ?            ?            ?
# 2792            ?            ?            ?            ?            ?
# 2793            ?            ?            ?            ?            ?
# 2794            ?            ?            ?            ?            ?
# 2795            ?            ?            ?            ?            ?
#
#      INTERNODE_29
# 2791            ?
# 2792            ?
# 2793            ?
# 2794            ?
# 2795            ?
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2796 entries, 0 to 2795
# Data columns (total 35 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   N             2796 non-null   int64
#  1   TR            2796 non-null   object
#  2   TREE          2796 non-null   object
#  3   BR            2796 non-null   object
#  4   TL            2796 non-null   float64
#  5   IN            2796 non-null   int64
#  6   INTERNODE_1   2796 non-null   float64
#  7   INTERNODE_2   2796 non-null   object
#  8   INTERNODE_3   2796 non-null   object
#  9   INTERNODE_4   2796 non-null   object
#  10  INTERNODE_5   2796 non-null   object
#  11  INTERNODE_6   2796 non-null   object
#  12  INTERNODE_7   2796 non-null   object
#  13  INTERNODE_8   2796 non-null   object
#  14  INTERNODE_9   2796 non-null   object
#  15  INTERNODE_10  2796 non-null   object
#  16  INTERNODE_11  2796 non-null   object
#  17  INTERNODE_12  2796 non-null   object
#  18  INTERNODE_13  2796 non-null   object
#  19  INTERNODE_14  2796 non-null   object
#  20  INTERNODE_15  2796 non-null   object
#  21  INTERNODE_16  2796 non-null   object
#  22  INTERNODE_17  2796 non-null   object
#  23  INTERNODE_18  2796 non-null   object
#  24  INTERNODE_19  2796 non-null   object
#  25  INTERNODE_20  2796 non-null   object
#  26  INTERNODE_21  2796 non-null   object
#  27  INTERNODE_22  2796 non-null   object
#  28  INTERNODE_23  2796 non-null   object
#  29  INTERNODE_24  2796 non-null   object
#  30  INTERNODE_25  2796 non-null   object
#  31  INTERNODE_26  2796 non-null   object
#  32  INTERNODE_27  2796 non-null   object
#  33  INTERNODE_28  2796 non-null   object
#  34  INTERNODE_29  2796 non-null   object
# dtypes: float64(2), int64(2), object(31)
# memory usage: 764.7+ KB

# %%
df.isnull().sum()
# Out:
# N               0
# TR              0
# TREE            0
# BR              0
# TL              0
# IN              0
# INTERNODE_1     0
# INTERNODE_2     0
# INTERNODE_3     0
# INTERNODE_4     0
# INTERNODE_5     0
# INTERNODE_6     0
# INTERNODE_7     0
# INTERNODE_8     0
# INTERNODE_9     0
# INTERNODE_10    0
# INTERNODE_11    0
# INTERNODE_12    0
# INTERNODE_13    0
# INTERNODE_14    0
# INTERNODE_15    0
# INTERNODE_16    0
# INTERNODE_17    0
# INTERNODE_18    0
# INTERNODE_19    0
# INTERNODE_20    0
# INTERNODE_21    0
# INTERNODE_22    0
# INTERNODE_23    0
# INTERNODE_24    0
# INTERNODE_25    0
# INTERNODE_26    0
# INTERNODE_27    0
# INTERNODE_28    0
# INTERNODE_29    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2791    False
# 2792    False
# 2793    False
# 2794    False
# 2795    False
# Length: 2796, dtype: bool

# %%
cat_clo=df.select_dtypes(include='object').columns
print(cat_clo)
# Out:
# Index(['TR', 'TREE', 'BR', 'INTERNODE_2', 'INTERNODE_3', 'INTERNODE_4',
#        'INTERNODE_5', 'INTERNODE_6', 'INTERNODE_7', 'INTERNODE_8',
#        'INTERNODE_9', 'INTERNODE_10', 'INTERNODE_11', 'INTERNODE_12',
#        'INTERNODE_13', 'INTERNODE_14', 'INTERNODE_15', 'INTERNODE_16',
#        'INTERNODE_17', 'INTERNODE_18', 'INTERNODE_19', 'INTERNODE_20',
#        'INTERNODE_21', 'INTERNODE_22', 'INTERNODE_23', 'INTERNODE_24',
#        'INTERNODE_25', 'INTERNODE_26', 'INTERNODE_27', 'INTERNODE_28',
#        'INTERNODE_29'],
#       dtype='object')

# %%
df.replace('?', np.nan, inplace=True)

# %%
df
# Out:
#          N           TR TREE BR    TL  IN  INTERNODE_1 INTERNODE_2  \
# 0        1      control  G28  A  75.0  15          1.0         2.3
# 1        2      control  G28  B  18.0   7          0.7         1.3
# 2        3      control  G28  C  46.0  11          0.5         1.0
# 3        4      control  G28  C  16.0   8          0.5         1.2
# 4        5      control  G28  D  56.0  16          0.5         1.0
# ...    ...          ...  ... ..   ...  ..          ...         ...
# 2791  2792  EL_500_4g/L  G24  I   1.0   4          0.3         0.3
# 2792  2793  EL_500_4g/L  G24  I   1.0   4          0.3         0.3
# 2793  2794  EL_500_4g/L  G24  I   1.0   4          0.3         0.3
# 2794  2795  EL_500_4g/L  G24  I   1.0   4          0.2         0.2
# 2795  2796  EL_500_4g/L  G24  I   1.0   3          0.3         0.3
#
#      INTERNODE_3 INTERNODE_4  ... INTERNODE_20 INTERNODE_21 INTERNODE_22  \
# 0            7.4         8.6  ...          NaN          NaN          NaN
# 1            4.0         5.2  ...          NaN          NaN          NaN
# 2            4.3         8.8  ...          NaN          NaN          NaN
# 3            3.5         4.2  ...          NaN          NaN          NaN
# 4            3.5         8.2  ...          NaN          NaN          NaN
# ...          ...         ...  ...          ...          ...          ...
# 2791         0.3         0.3  ...          NaN          NaN          NaN
# 2792         0.3         0.3  ...          NaN          NaN          NaN
# 2793         0.3         0.3  ...          NaN          NaN          NaN
# 2794         0.2         0.2  ...          NaN          NaN          NaN
# 2795         0.3         NaN  ...          NaN          NaN          NaN
#
#      INTERNODE_23 INTERNODE_24 INTERNODE_25 INTERNODE_26 INTERNODE_27  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 2791          NaN          NaN          NaN          NaN          NaN
# 2792          NaN          NaN          NaN          NaN          NaN
# 2793          NaN          NaN          NaN          NaN          NaN
# 2794          NaN          NaN          NaN          NaN          NaN
# 2795          NaN          NaN          NaN          NaN          NaN
#
#      INTERNODE_28 INTERNODE_29
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 2791          NaN          NaN
# 2792          NaN          NaN
# 2793          NaN          NaN
# 2794          NaN          NaN
# 2795          NaN          NaN
#
# [2796 rows x 35 columns]

# %%
# Convertir les colonnes INTERNODE en float
internode_cols = [col for col in df.columns if col.startswith('INTERNODE')]
df[internode_cols] = df[internode_cols].astype(float)

# %%
#Gérer les valeurs manquantes (NaN) -> Remplir avec les valeurs moyenne
df[internode_cols] = df[internode_cols].fillna(df[internode_cols].mean())

# %%
from sklearn.preprocessing import OrdinalEncoder

cat_cols = df.select_dtypes(include='object').columns
encoder = OrdinalEncoder()
df[cat_cols] = encoder.fit_transform(df[cat_cols])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2796 entries, 0 to 2795
# Data columns (total 35 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   N             2796 non-null   int64
#  1   TR            2796 non-null   float64
#  2   TREE          2796 non-null   float64
#  3   BR            2784 non-null   float64
#  4   TL            2796 non-null   float64
#  5   IN            2796 non-null   int64
#  6   INTERNODE_1   2796 non-null   float64
#  7   INTERNODE_2   2796 non-null   float64
#  8   INTERNODE_3   2796 non-null   float64
#  9   INTERNODE_4   2796 non-null   float64
#  10  INTERNODE_5   2796 non-null   float64
#  11  INTERNODE_6   2796 non-null   float64
#  12  INTERNODE_7   2796 non-null   float64
#  13  INTERNODE_8   2796 non-null   float64
#  14  INTERNODE_9   2796 non-null   float64
#  15  INTERNODE_10  2796 non-null   float64
#  16  INTERNODE_11  2796 non-null   float64
#  17  INTERNODE_12  2796 non-null   float64
#  18  INTERNODE_13  2796 non-null   float64
#  19  INTERNODE_14  2796 non-null   float64
#  20  INTERNODE_15  2796 non-null   float64
#  21  INTERNODE_16  2796 non-null   float64
#  22  INTERNODE_17  2796 non-null   float64
#  23  INTERNODE_18  2796 non-null   float64
#  24  INTERNODE_19  2796 non-null   float64
#  25  INTERNODE_20  2796 non-null   float64
#  26  INTERNODE_21  2796 non-null   float64
#  27  INTERNODE_22  2796 non-null   float64
#  28  INTERNODE_23  2796 non-null   float64
#  29  INTERNODE_24  2796 non-null   float64
#  30  INTERNODE_25  2796 non-null   float64
#  31  INTERNODE_26  2796 non-null   float64
#  32  INTERNODE_27  2796 non-null   float64
#  33  INTERNODE_28  2796 non-null   float64
#  34  INTERNODE_29  2796 non-null   float64
# dtypes: float64(33), int64(2)
# memory usage: 764.7 KB

# %%
df.drop(['BR'], axis=1)
# Out:
#          N   TR  TREE    TL  IN  INTERNODE_1  INTERNODE_2  INTERNODE_3  \
# 0        1  4.0  15.0  75.0  15          1.0          2.3          7.4
# 1        2  4.0  15.0  18.0   7          0.7          1.3          4.0
# 2        3  4.0  15.0  46.0  11          0.5          1.0          4.3
# 3        4  4.0  15.0  16.0   8          0.5          1.2          3.5
# 4        5  4.0  15.0  56.0  16          0.5          1.0          3.5
# ...    ...  ...   ...   ...  ..          ...          ...          ...
# 2791  2792  1.0  13.0   1.0   4          0.3          0.3          0.3
# 2792  2793  1.0  13.0   1.0   4          0.3          0.3          0.3
# 2793  2794  1.0  13.0   1.0   4          0.3          0.3          0.3
# 2794  2795  1.0  13.0   1.0   4          0.2          0.2          0.2
# 2795  2796  1.0  13.0   1.0   3          0.3          0.3          0.3
#
#       INTERNODE_4  INTERNODE_5  ...  INTERNODE_20  INTERNODE_21  INTERNODE_22  \
# 0        8.600000     6.700000  ...      1.544186      1.423077      1.188235
# 1        5.200000     2.800000  ...      1.544186      1.423077      1.188235
# 2        8.800000     6.800000  ...      1.544186      1.423077      1.188235
# 3        4.200000     2.200000  ...      1.544186      1.423077      1.188235
# 4        8.200000     5.300000  ...      1.544186      1.423077      1.188235
# ...           ...          ...  ...           ...           ...           ...
# 2791     0.300000     3.645922  ...      1.544186      1.423077      1.188235
# 2792     0.300000     3.645922  ...      1.544186      1.423077      1.188235
# 2793     0.300000     3.645922  ...      1.544186      1.423077      1.188235
# 2794     0.200000     3.645922  ...      1.544186      1.423077      1.188235
# 2795     3.025818     3.645922  ...      1.544186      1.423077      1.188235
#
#       INTERNODE_23  INTERNODE_24  INTERNODE_25  INTERNODE_26  INTERNODE_27  \
# 0             0.95      0.842857          0.95           2.2           1.2
# 1             0.95      0.842857          0.95           2.2           1.2
# 2             0.95      0.842857          0.95           2.2           1.2
# 3             0.95      0.842857          0.95           2.2           1.2
# 4             0.95      0.842857          0.95           2.2           1.2
# ...            ...           ...           ...           ...           ...
# 2791          0.95      0.842857          0.95           2.2           1.2
# 2792          0.95      0.842857          0.95           2.2           1.2
# 2793          0.95      0.842857          0.95           2.2           1.2
# 2794          0.95      0.842857          0.95           2.2           1.2
# 2795          0.95      0.842857          0.95           2.2           1.2
#
#       INTERNODE_28  INTERNODE_29
# 0              0.9           0.3
# 1              0.9           0.3
# 2              0.9           0.3
# 3              0.9           0.3
# 4              0.9           0.3
# ...            ...           ...
# 2791           0.9           0.3
# 2792           0.9           0.3
# 2793           0.9           0.3
# 2794           0.9           0.3
# 2795           0.9           0.3
#
# [2796 rows x 34 columns]

# %%
df.nunique().count()
# Out:
# np.int64(35)

# %%
plt.figure(figsize=(36,26))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('correlation heatmap')
plt.show()

# %%
x=df.drop(['TR'], axis=1)
y=df['TR']

# %%
x
# Out:
#          N  TREE   BR    TL  IN  INTERNODE_1  INTERNODE_2  INTERNODE_3  \
# 0        1  15.0  0.0  75.0  15          1.0          2.3          7.4
# 1        2  15.0  1.0  18.0   7          0.7          1.3          4.0
# 2        3  15.0  2.0  46.0  11          0.5          1.0          4.3
# 3        4  15.0  2.0  16.0   8          0.5          1.2          3.5
# 4        5  15.0  3.0  56.0  16          0.5          1.0          3.5
# ...    ...   ...  ...   ...  ..          ...          ...          ...
# 2791  2792  13.0  8.0   1.0   4          0.3          0.3          0.3
# 2792  2793  13.0  8.0   1.0   4          0.3          0.3          0.3
# 2793  2794  13.0  8.0   1.0   4          0.3          0.3          0.3
# 2794  2795  13.0  8.0   1.0   4          0.2          0.2          0.2
# 2795  2796  13.0  8.0   1.0   3          0.3          0.3          0.3
#
#       INTERNODE_4  INTERNODE_5  ...  INTERNODE_20  INTERNODE_21  INTERNODE_22  \
# 0        8.600000     6.700000  ...      1.544186      1.423077      1.188235
# 1        5.200000     2.800000  ...      1.544186      1.423077      1.188235
# 2        8.800000     6.800000  ...      1.544186      1.423077      1.188235
# 3        4.200000     2.200000  ...      1.544186      1.423077      1.188235
# 4        8.200000     5.300000  ...      1.544186      1.423077      1.188235
# ...           ...          ...  ...           ...           ...           ...
# 2791     0.300000     3.645922  ...      1.544186      1.423077      1.188235
# 2792     0.300000     3.645922  ...      1.544186      1.423077      1.188235
# 2793     0.300000     3.645922  ...      1.544186      1.423077      1.188235
# 2794     0.200000     3.645922  ...      1.544186      1.423077      1.188235
# 2795     3.025818     3.645922  ...      1.544186      1.423077      1.188235
#
#       INTERNODE_23  INTERNODE_24  INTERNODE_25  INTERNODE_26  INTERNODE_27  \
# 0             0.95      0.842857          0.95           2.2           1.2
# 1             0.95      0.842857          0.95           2.2           1.2
# 2             0.95      0.842857          0.95           2.2           1.2
# 3             0.95      0.842857          0.95           2.2           1.2
# 4             0.95      0.842857          0.95           2.2           1.2
# ...            ...           ...           ...           ...           ...
# 2791          0.95      0.842857          0.95           2.2           1.2
# 2792          0.95      0.842857          0.95           2.2           1.2
# 2793          0.95      0.842857          0.95           2.2           1.2
# 2794          0.95      0.842857          0.95           2.2           1.2
# 2795          0.95      0.842857          0.95           2.2           1.2
#
#       INTERNODE_28  INTERNODE_29
# 0              0.9           0.3
# 1              0.9           0.3
# 2              0.9           0.3
# 3              0.9           0.3
# 4              0.9           0.3
# ...            ...           ...
# 2791           0.9           0.3
# 2792           0.9           0.3
# 2793           0.9           0.3
# 2794           0.9           0.3
# 2795           0.9           0.3
#
# [2796 rows x 34 columns]

# %%
y
# Out:
# 0       4.0
# 1       4.0
# 2       4.0
# 3       4.0
# 4       4.0
#        ...
# 2791    1.0
# 2792    1.0
# 2793    1.0
# 2794    1.0
# 2795    1.0
# Name: TR, Length: 2796, dtype: float64

# %%
# Pour chaque colonne catégorielle, on vérifie si elle est fortement liée à la classe TR
cat_cols = ['TREE', 'IN', 'TL']  # ajuste selon ton dataset

for col in cat_cols:
    print(f"Colonne: {col}")
    print(df.groupby('TR')[col].nunique())
    print("\n")
# Out:
# Colonne: TREE
# TR
# 0.0     9
# 1.0     9
# 2.0    10
# 3.0    10
# 4.0     9
# 5.0    10
# Name: TREE, dtype: int64
#
#
# Colonne: IN
# TR
# 0.0    20
# 1.0    24
# 2.0    21
# 3.0    26
# 4.0    21
# 5.0    24
# Name: IN, dtype: int64
#
#
# Colonne: TL
# TR
# 0.0    42
# 1.0    47
# 2.0    36
# 3.0    81
# 4.0    87
# 5.0    90
# Name: TL, dtype: int64

# %%
cols_to_drop = ['TREE', 'BR']  # adapte selon analyse

X = df.drop(cols_to_drop + ['TR'], axis=1)
y = df['TR']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd


# Étape 2 : split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.3, random_state=500)

# Étape 3 : définir les modèles
models = {
    'Decision Tree': DecisionTreeClassifier(max_depth=3, random_state=500),
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=500),
    'SVC (RBF)': make_pipeline(StandardScaler(), SVC(kernel='rbf', C=1.0, random_state=500)),
    'KNN': make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=5)),
    'Logistic Regression': make_pipeline(StandardScaler(), LogisticRegression(max_iter=1000, random_state=808))
}

# Étape 4 : entraînement et évaluation
results = []

for name, model in models.items():
    model.fit(X_train, y_train)
    
    train_acc = accuracy_score(y_train, model.predict(X_train))
    test_acc = accuracy_score(y_test, model.predict(X_test))
    
    results.append({
        'Modèle': name,
        'Train Accuracy': round(train_acc, 4),
        'Test Accuracy': round(test_acc, 4)
    })

# Étape 5 : afficher les résultats
results_df = pd.DataFrame(results)
print(results_df.sort_values(by="Test Accuracy", ascending=False))
# Out:
#                 Modèle  Train Accuracy  Test Accuracy
# 0        Decision Tree          1.0000         0.9959
# 1        Random Forest          1.0000         0.9535
# 4  Logistic Regression          0.9356         0.8774
# 2            SVC (RBF)          0.9105         0.8340
# 3                  KNN          0.8437         0.7942

# %%
# Decision Tree classifier
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train) 
y_pred_dt = dt_model.predict(X_test)

# %%
# Tri des résultats pour meilleur affichage
results_df_sorted = results_df.sort_values(by='Test Accuracy', ascending=True)

# Création du graphique
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Barplot des performances test
sns.barplot(data=results_df_sorted, x='Test Accuracy', y='Modèle', color='skyblue', label='Test')
sns.barplot(data=results_df_sorted, x='Train Accuracy', y='Modèle', color='lightgreen', label='Train', alpha=0.5)

plt.title('Comparaison des performances des modèles')
plt.xlabel('Accuracy')
plt.ylabel('Modèles')
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_auc_score
train_auc = roc_auc_score(y_train, model.predict_proba(X_train), multi_class='ovr')
test_auc = roc_auc_score(y_test, model.predict_proba(X_test), multi_class='ovr')
print("train",train_auc)
print("test", test_auc)
# Out:
# train 0.995348177005845
# test 0.9766925152264206

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Exemple : TL vs INTERNODE_1 coloré par TR
sns.scatterplot(data=df, x='TL', y='INTERNODE_1', hue='TR')
plt.title("Séparation naturelle ?")
plt.show()

# %%
results_df.to_csv("comparaison_modeles.csv", index=False)

# %%
import pickle

model_file_name = "tree_model.pkl"

try:
    with open(model_file_name, 'wb') as file:
        pickle.dump(dt_model, file)
    print(f"Model saved successfully to {model_file_name}")
except Exception as e:
    print(f"Error saving the model: {e}")
# Out:
# Model saved successfully to tree_model.pkl
